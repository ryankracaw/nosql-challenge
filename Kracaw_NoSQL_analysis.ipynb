# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene' : 20}

# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establishments.count_documents(query))

# Display the first document in the results using pprint
results = establishments.find(query)
for i in range(1):
    pprint(results[i])
# Out:
# Number of documents in result: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('648b27f33a47133e6dfde73a'),
#  'geocode': {'latitude': '50.769705', 'longitude': '0.27694'},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  648b27f33a47133e6dfde73a   110681                  0
# 1  648b27f33a47133e6dfdeabb   612039                  0
# 2  648b27f33a47133e6dfdedc5   730933                  0
# 3  648b27f33a47133e6dfdefb3   172735                  0
# 4  648b27f33a47133e6dfdefc2   172953                  0
# 5  648b27f43a47133e6dfdf961   512854                  0
# 6  648b27f43a47133e6dfdfb82  1537089                  0
# 7  648b27f53a47133e6dfe10ad   155648                  0
# 8  648b27f53a47133e6dfe14f1  1012883                  0
# 9  648b27f63a47133e6dfe1d03   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '0.27694', 'latitude': '50.769705'}
# 1  {'longitude': '1.278721', 'latitude': '51.8575...
# 2  {'longitude': '1.15927', 'latitude': '51.789429'}
# 3  {'longitude': '0.10202', 'latitude': '50.770885'}
# 4  {'longitude': '0.101446', 'latitude': '50.7707...
# 5  {'longitude': '0.736349', 'latitude': '51.5414...
# 6  {'longitude': '0.7121671', 'latitude': '51.535...
# 7  {'longitude': '0.602364', 'latitude': '51.5915...
# 8  {'longitude': '0.146449998021126', 'latitude':...
# 9  {'longitude': '0.462307', 'latitude': '51.57005'}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links latitude longitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 1  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 2  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 3  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 4  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 5  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 6  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'RatingValue' : {'$gt' : 4}}

# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establishments.count_documents(query))

# Display the first document in the results using pprint
results = establishments.find(query)
for i in range(1):
    pprint(results[i])
# Out:
# Number of documents in result: 25816
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('648b27f23a47133e6dfdcc08'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  25816
#                         _id   FHRSID  ChangesByServerID  \
# 0  648b27f23a47133e6dfdcc08  1043695                  0
# 1  648b27f23a47133e6dfdcc0a   289353                  0
# 2  648b27f23a47133e6dfdcc0d   289352                  0
# 3  648b27f23a47133e6dfdcc0e   289560                  0
# 4  648b27f23a47133e6dfdcc10   344689                  0
# 5  648b27f23a47133e6dfdcc11   894592                  0
# 6  648b27f23a47133e6dfdcc12  1043701                  0
# 7  648b27f23a47133e6dfdcc14   805703                  0
# 8  648b27f23a47133e6dfdcc15  1071930                  0
# 9  648b27f23a47133e6dfdcc16  1068284                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000073616                         The Pavilion
# 1             PI/000002468  St Marys COE (aided) Primary School
# 2             PI/000002460                             The Ship
# 3             PI/000039927                              Mariner
# 4             PI/000002095             Folkestone Trawlers Shop
# 5             PI/000074396                               Docker
# 6             PI/000076360                      Pick Up Pintxos
# 7             PI/000073221            That Burger - Harbour Arm
# 8             PI/000076531                         The Club Hut
# 9             PI/000076532                        The Tea Caddy
#
#                 BusinessType  BusinessTypeID  \
# 0    Restaurant/Cafe/Canteen               1
# 1  School/college/university            7845
# 2          Pub/bar/nightclub            7843
# 3          Pub/bar/nightclub            7843
# 4          Retailers - other            4613
# 5          Retailers - other            4613
# 6     Takeaway/sandwich shop            7844
# 7     Takeaway/sandwich shop            7844
# 8          Pub/bar/nightclub            7843
# 9             Mobile caterer            7846
#
#                                 AddressLine1           AddressLine2  \
# 0                        East Cliff Pavilion          Wear Bay Road
# 1  St Marys Church Of England Primary School            Warren Road
# 2                               23 The Stade             Folkestone
# 3                               16 The Stade             Folkestone
# 4                                1 The Stade             Folkestone
# 5                         Folkestone Harbour  Harbour Approach Road
# 6                         Folkestone Harbour  Harbour Approach Road
# 7                         Folkestone Harbour  Harbour Approach Road
# 8                         Folkestone Harbour  Harbour Approach Road
# 9                         Folkestone Harbour  Harbour Approach Road
#
#   AddressLine3  ...                                             scores  \
# 0   Folkestone  ...  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...
# 1   Folkestone  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 2         Kent  ...  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...
# 3         Kent  ...  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 4         Kent  ...  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 5   Folkestone  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 6   Folkestone  ...  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...
# 7   Folkestone  ...  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...
# 8   Folkestone  ...  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 9   Folkestone  ...  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...
#
#   SchemeType                                            geocode  RightToReply  \
# 0       FHRS  {'longitude': '1.195625', 'latitude': '51.0838...
# 1       FHRS  {'longitude': '1.194762', 'latitude': '51.0857...
# 2       FHRS  {'longitude': '1.188537', 'latitude': '51.08084'}
# 3       FHRS  {'longitude': '1.188537', 'latitude': '51.08084'}
# 4       FHRS  {'longitude': '1.188537', 'latitude': '51.08084'}
# 5       FHRS  {'longitude': '1.18590330311705', 'latitude': ...
# 6       FHRS  {'longitude': '1.18590330311705', 'latitude': ...
# 7       FHRS  {'longitude': '1.18590330311705', 'latitude': ...
# 8       FHRS  {'longitude': '1.18590330311705', 'latitude': ...
# 9       FHRS  {'longitude': '1.18590330311705', 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4591.765489            False
# 1  4591.871474            False
# 2  4591.912145            False
# 3  4591.912145            False
# 4  4591.912145            False
# 5  4591.914705            False
# 6  4591.914705            False
# 7  4591.914705            False
# 8  4591.914705            False
# 9  4591.914705            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links latitude longitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 1  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 2  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 3  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 4  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 5  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 6  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 7  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 8  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 9  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 
longitude = 

query = 
sort =  

# Print the results

# %%
# Convert result to Pandas DataFrame
result_df = pd.DataFrame(results)

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match_query = {'$match' : {'scores.Hygiene' : 0}}
group_query = {'$group' : {'LocalAuthorityName' : "$scores.Hygiene"}}
sort_values = {'$sort' : {'scores.Hygiene' : -1}}

pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))
# Print the number of documents in the result
print("Number of classifications in result: ", len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[27], line 10
#       7 sort_values = {'$sort' : {'scores.Hygiene' : -1}}
#       9 pipeline = [match_query, group_query, sort_values]
# ---> 10 results = list(establishments.aggregate(pipeline))
#      11 # Print the number of documents in the result
#      12 print("Number of classifications in result: ", len(results))
#
# File c:\Users\Ryan Kracaw\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:2436, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2358 """Perform an aggregation using the aggregation framework on this
#    2359 collection.
#    2360
#    (...)
#    2432     https://mongodb.com/docs/manual/reference/command/aggregate
#    2433 """
#    2435 with self.__database.client._tmp_session(session, close=False) as s:
# -> 2436     return self._aggregate(
#    2437         _CollectionAggregationCommand,
#    2438         pipeline,
#    2439         CommandCursor,
#    2440         session=s,
#    2441         explicit_session=session is not None,
#    2442         let=let,
#    2443         comment=comment,
#    2444         **kwargs,
#    2445     )
#
# File c:\Users\Ryan Kracaw\anaconda3\envs\dev\lib\site-packages\pymongo\_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File c:\Users\Ryan Kracaw\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:2343, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2332     kwargs["comment"] = comment
#    2333 cmd = aggregation_command(
#    2334     self,
#    2335     cursor_class,
#    (...)
#    2340     user_fields={"cursor": {"firstBatch": 1}},
#    2341 )
# -> 2343 return self.__database.client._retryable_read(
#    2344     cmd.get_cursor,
#    2345     cmd.get_read_preference(session),
#    2346     session,
#    2347     retryable=not cmd._performs_write,
#    2348 )
#
# File c:\Users\Ryan Kracaw\anaconda3\envs\dev\lib\site-packages\pymongo\_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File c:\Users\Ryan Kracaw\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:1448, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1446             assert last_error is not None
#    1447             raise last_error
# -> 1448         return func(session, server, sock_info, read_pref)
#    1449 except ServerSelectionTimeoutError:
#    1450     if retrying:
#    1451         # The application may think the write was never attempted
#    1452         # if we raise ServerSelectionTimeoutError on the retry
#    1453         # attempt. Raise the original exception instead.
#
# File c:\Users\Ryan Kracaw\anaconda3\envs\dev\lib\site-packages\pymongo\aggregation.py:142, in _AggregationCommand.get_cursor(self, session, server, sock_info, read_preference)
#     139     write_concern = None
#     141 # Run command.
# --> 142 result = sock_info.command(
#     143     self._database.name,
#     144     cmd,
#     145     read_preference,
#     146     self._target.codec_options,
#     147     parse_write_concern_error=True,
#     148     read_concern=read_concern,
#     149     write_concern=write_concern,
#     150     collation=self._collation,
#     151     session=session,
#     152     client=self._database.client,
#     153     user_fields=self._user_fields,
#     154 )
#     156 if self._result_processor:
#     157     self._result_processor(result, sock_info)
#
# File c:\Users\Ryan Kracaw\anaconda3\envs\dev\lib\site-packages\pymongo\pool.py:767, in SocketInfo.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     765     self._raise_if_not_writable(unacknowledged)
#     766 try:
# --> 767     return command(
#     768         self,
#     769         dbname,
#     770         spec,
#     771         self.is_mongos,
#     772         read_preference,
#     773         codec_options,
#     774         session,
#     775         client,
#     776         check,
#     777         allowable_errors,
#     778         self.address,
#     779         listeners,
#     780         self.max_bson_size,
#     781         read_concern,
#     782         parse_write_concern_error=parse_write_concern_error,
#     783         collation=collation,
#     784         compression_ctx=self.compression_context,
#     785         use_op_msg=self.op_msg_enabled,
#     786         unacknowledged=unacknowledged,
#     787         user_fields=user_fields,
#     788         exhaust_allowed=exhaust_allowed,
#     789         write_concern=write_concern,
#     790     )
#     791 except (OperationFailure, NotPrimaryError):
#     792     raise
#
# File c:\Users\Ryan Kracaw\anaconda3\envs\dev\lib\site-packages\pymongo\network.py:166, in command(sock_info, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     164             client._process_response(response_doc, session)
#     165         if check:
# --> 166             helpers._check_command_response(
#     167                 response_doc,
#     168                 sock_info.max_wire_version,
#     169                 allowable_errors,
#     170                 parse_write_concern_error=parse_write_concern_error,
#     171             )
#     172 except Exception as exc:
#     173     if publish:
#
# File c:\Users\Ryan Kracaw\anaconda3\envs\dev\lib\site-packages\pymongo\helpers.py:181, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     178 elif code == 43:
#     179     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 181 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: The field 'LocalAuthorityName' must be an accumulator object, full error: {'ok': 0.0, 'errmsg': "The field 'LocalAuthorityName' must be an accumulator object", 'code': 40234, 'codeName': 'Location40234'}

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
